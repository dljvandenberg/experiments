# %%
# Generated by Selenium IDE
import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys

class Scraper():  
  def setup_chrome(self, exec_path):
    self.driver = webdriver.Chrome(executable_path = exec_path)
    self.vars = {}
  
  def teardown_method(self, method):
    self.driver.quit()
  
  def get_cardano(self):
    self.driver.get("https://coinmarketcap.com/")
    self.driver.find_element(By.CSS_SELECTOR, ".cmc-quick-search__input").click()
    self.driver.find_element(By.CSS_SELECTOR, ".cmc-quick-search__input").send_keys("cardano")
    self.driver.find_element(By.CSS_SELECTOR, ".cmc-quick-search__input").send_keys(Keys.ENTER)
    self.driver.execute_script("window.scrollTo(0,638)")
    self.driver.find_element(By.CSS_SELECTOR, ".highcharts-button-hover > text").click()
    self.driver.find_element(By.CSS_SELECTOR, ".highcharts-series-1 tspan").click()
    self.driver.find_element(By.CSS_SELECTOR, ".highcharts-series-1 tspan").click()
  
  def test_cardano(self):
    self.driver.get("https://coinmarketcap.com/")
    self.driver.set_window_size(1440, 877)
    self.driver.find_element(By.CSS_SELECTOR, ".cmc-quick-search__input").click()
    self.driver.find_element(By.CSS_SELECTOR, ".cmc-quick-search__input").send_keys("cardano")
    self.driver.find_element(By.CSS_SELECTOR, ".cmc-quick-search__input").send_keys(Keys.ENTER)
    time.sleep(1)
    self.driver.execute_script("window.scrollTo(0,533)")
    time.sleep(1)
    self.driver.find_element(By.LINK_TEXT, "Historical Data").click()

# %%
scraper = Scraper()
scraper.setup_chrome(exec_path = './chromedriver')
#scraper.get_cardano()
scraper.test_cardano()
